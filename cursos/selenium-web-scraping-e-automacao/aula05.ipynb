# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

chrome = webdriver.Chrome()

# %%
# Exemplo 01
# https://curso-web-scraping.pages.dev/#/exemplo/1
# server local
pagina = 'http://localhost:8000/#/exemplo/1'
chrome.get(pagina)

# %%
# Filtrar por Classe
# CLASS_NAME
lista_input = chrome.find_elements(By.CLASS_NAME, 'styled-input')
lista_input
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e06b756b28097d26217d4fcfb2893205", element="f.CFA79D103450B71BC16C27D6AC9B2420.d.67F27C723F520E8D3C282B4F4E15E361.e.4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e06b756b28097d26217d4fcfb2893205", element="f.CFA79D103450B71BC16C27D6AC9B2420.d.67F27C723F520E8D3C282B4F4E15E361.e.6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e06b756b28097d26217d4fcfb2893205", element="f.CFA79D103450B71BC16C27D6AC9B2420.d.67F27C723F520E8D3C282B4F4E15E361.e.8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e06b756b28097d26217d4fcfb2893205", element="f.CFA79D103450B71BC16C27D6AC9B2420.d.67F27C723F520E8D3C282B4F4E15E361.e.10")>]

# %%
for item in lista_input:
    print(item.get_property('value'))
# Out:
# Alícia Braga Neto
# Central Fatores Facilitador
# Câncer
# Masculino

# %%
# Com duas ou mais classes: styled-input e optional-info. (separar com .)
lista_classes = chrome.find_elements(By.CLASS_NAME, 'styled-input.optional-info')
lista_classes
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e06b756b28097d26217d4fcfb2893205", element="f.CFA79D103450B71BC16C27D6AC9B2420.d.67F27C723F520E8D3C282B4F4E15E361.e.8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e06b756b28097d26217d4fcfb2893205", element="f.CFA79D103450B71BC16C27D6AC9B2420.d.67F27C723F520E8D3C282B4F4E15E361.e.10")>]

# %%
for ele in lista_classes:
    print(ele.get_property('value'))
# Out:
# Câncer
# Masculino
