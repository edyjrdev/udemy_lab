# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import json

chrome = webdriver.Chrome()

# %%
# Desafio 01
# https://curso-web-scraping.pages.dev/#/desafio/1
# server local
pagina = 'http://localhost:8000/#/desafio/1'
chrome.get(pagina)

# %% [markdown]
# Ler arquivo desafio_1.json
# para cada registro preencher formulario e enviar

# %%
# Abre o arquivo para leitura
with open('./desafio_1.json', 'r', encoding='utf-8') as arquivo:
    # Converte o conteúdo JSON em um objeto Python (dicionário/lista)
    lista_dados = json.load(arquivo)

# Exemplo de acesso aos dados
for registro in lista_dados:
    email = registro['email']
    senha =  registro['senha']
    data_nascimento = registro['data-de-nascimento']
    liga_newsletter = registro['newsletter']
    data_nasc = (data_nascimento.split('-'))
    print (email, senha, data_nasc, liga_newsletter, sep='|')

    # Mapear Formulario
    in_email = chrome.find_element(By.NAME, 'email')
    in_senha = chrome.find_element(By.NAME, 'senha')
    sel_dia = Select(chrome.find_element(By.NAME, 'dia'))
    sel_mes = Select(chrome.find_element(By.NAME, 'mes'))
    sel_ano = Select(chrome.find_element(By.NAME, 'ano'))
    bt_check = chrome.find_element(By.CSS_SELECTOR, 'button#airplane-mode')
    print(bt_check.get_property('value'))
    # Limpar Formulario
    in_email.clear()
    in_senha.clear()
    
    # Preencher Formulario
    in_email.send_keys(email)
    in_senha.send_keys(senha)
    sel_dia.select_by_visible_text(str(int(data_nasc[2])))
    sel_mes.select_by_visible_text(str(int(data_nasc[1])))
    sel_ano.select_by_visible_text(data_nasc[0])
    if liga_newsletter:
        bt_check.click()
    in_email.submit()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Abre o arquivo para leitura
# ----> 2 with open('.venv/desafio_1.json', 'r', encoding='utf-8') as arquivo:
#       3     # Converte o conteúdo JSON em um objeto Python (dicionário/lista)
#       4     lista_dados = json.load(arquivo)
#       6 # Exemplo de acesso aos dados
#
# File c:\edyjrdev\udemy_lab\cursos\selenium-web-scraping-e-automacao\.venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '.venv/desafio_1.json'
