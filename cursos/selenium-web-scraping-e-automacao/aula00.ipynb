# %%
# !pip install selenium
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip show selenium
# Out:
# Name: selenium
# Version: 4.40.0
# Summary: Official Python bindings for Selenium WebDriver
# Home-page: https://www.selenium.dev
# Author:
# Author-email:
# License: Apache-2.0
# Location: C:\edyjrdev\udemy_lab\cursos\selenium-web-scraping-e-automacao\.venv\Lib\site-packages
# Requires: certifi, trio, trio-typing, trio-websocket, types-certifi, types-urllib3, typing_extensions, urllib3, websocket-client
# Required-by:

# %%
# Baixar Driver do Selenium
from selenium import webdriver
from IPython.display import HTML
#Chrome
chrome = webdriver.Chrome()
#Firefox
# firefox = webdriver.Firefox()
#Edge
# edge = webdriver.Edge()

print('Navegador aberto.')
# Out:
# Navegador aberto.

# %%
# Ir para Pagina
chrome.get('https://www.google.com.br')

# %%
chrome.current_url
# Out:
# 'https://www.google.com/'

# %%
chrome.title
# Out:
# 'Google'

# %%
# Manipular Janela
chrome.fullscreen_window()
#dimensão e coordenadas da janela 
chrome.get_window_rect()
# Out:
# {'height': 1080, 'width': 1920, 'x': 0, 'y': 0}

# %%
chrome.maximize_window()

# %%
chrome.minimize_window()

# %%
chrome.set_window_rect(x=950, y=0, height=800, width=800)
# Out:
# {'height': 800, 'width': 800, 'x': 950, 'y': 0}

# %%
chrome.name
# Out:
# 'chrome'

# %%
# Conteudo da Página HTML
# HTML(chrome.page_source)

# %%
chrome.refresh()

# %%
chrome.get('https://www.bb.com.br')

# %%
chrome.back()

# %%
chrome.forward()

# %%
chrome.quit()
