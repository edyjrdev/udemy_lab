# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.common import NoSuchElementException, TimeoutException
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# Estrutura DTO (dataclass)
from dataclasses import dataclass

chrome = webdriver.Chrome()

# %%
# Exemplo 01
# https://curso-web-scraping.pages.dev/#/exemplo/8
# server local
pagina = 'http://localhost:8000/#/exemplo/8'
chrome.get(pagina)
chrome.implicitly_wait(time_to_wait=10)  # aguardar 10 seg antes de levantar exceção

# %%
""" <table id="tabela-usuarios" class="w-full text-sm text-left rtl:text-right text-gray-500 dark:text-gray-400"><thead class="text-xs text-gray-700 uppercase bg-gray-50 dark:bg-gray-700 dark:text-gray-400"><tr><th scope="col" class="px-6 py-3">Avatar</th><th scope="col" class="px-6 py-3">Nome completo</th><th scope="col" class="px-6 py-3">Profissão</th><th scope="col" class="px-6 py-3">E-mail</th><th scope="col" class="px-6 py-3">Perfil</th><th scope="col" class="px-6 py-3">Estado</th></tr></thead><tbody><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/146.jpg" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Suélen Xavier</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Diretor</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">suelen_xavier@example.com</th><td class="px-6 py-4">suelen.xavier24</td><td class="px-6 py-4">Alagoas</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://avatars.githubusercontent.com/u/27483515" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Manuela Albuquerque Jr.</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Diretor</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">manuela.albuquerque14@example.net</th><td class="px-6 py-4">manuela.albuquerque</td><td class="px-6 py-4">Amazonas</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://avatars.githubusercontent.com/u/13694853" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Yasmin Santos</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Atentende</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">yasmin.santos@example.org</th><td class="px-6 py-4">yasmin.santos</td><td class="px-6 py-4">Goiás</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/61.jpg" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Elísio Macedo</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Policial</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">elisio_macedo80@example.org</th><td class="px-6 py-4">elisio.macedo</td><td class="px-6 py-4">Amazonas</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/588.jpg" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Dra. Gúbio Reis</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Representante</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">gubio_reis0@example.com</th><td class="px-6 py-4">gubio.reis</td><td class="px-6 py-4">Acre</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/1230.jpg" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Melissa Saraiva Filho</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Atentende</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">melissa_saraiva@example.com</th><td class="px-6 py-4">melissa.saraiva70</td><td class="px-6 py-4">Sergipe</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/634.jpg" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Rafaela Barros</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Assistente</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">rafaela_barros44@example.net</th><td class="px-6 py-4">rafaela_barros12</td><td class="px-6 py-4">Rondônia</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://avatars.githubusercontent.com/u/79010193" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Júlio Xavier</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Produtor</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">julio.xavier@example.org</th><td class="px-6 py-4">julio.xavier8</td><td class="px-6 py-4">Amapá</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://avatars.githubusercontent.com/u/17326553" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Lorraine Melo Filho</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Associado</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">lorraine.melo@example.com</th><td class="px-6 py-4">lorraine.melo25</td><td class="px-6 py-4">Goiás</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/1072.jpg" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Sirineu Moreira</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Estrategista</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">sirineu.moreira@example.org</th><td class="px-6 py-4">sirineu.moreira90</td><td class="px-6 py-4">Distrito Federal</td></tr></tbody></table>
"""
dados = chrome.find_element(By.ID, 'tabela-usuarios')
dados
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5090d866c4b6cb2f89cf28e04e5e1526", element="f.22751EF508D4BC5157A743CF572D2313.d.7D2119D10D542729E59FCF6E22462972.e.14")>

# %%
# linha de dado
""" 
<tbody>
<tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/146.jpg" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Suélen Xavier</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Diretor</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">suelen_xavier@example.com</th><td class="px-6 py-4">suelen.xavier24</td><td class="px-6 py-4">Alagoas</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://avatars.githubusercontent.com/u/27483515" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Manuela Albuquerque Jr.</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Diretor</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">manuela.albuquerque14@example.net</th><td class="px-6 py-4">manuela.albuquerque</td><td class="px-6 py-4">Amazonas</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://avatars.githubusercontent.com/u/13694853" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Yasmin Santos</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Atentende</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">yasmin.santos@example.org</th><td class="px-6 py-4">yasmin.santos</td><td class="px-6 py-4">Goiás</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/61.jpg" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Elísio Macedo</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Policial</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">elisio_macedo80@example.org</th><td class="px-6 py-4">elisio.macedo</td><td class="px-6 py-4">Amazonas</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/588.jpg" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Dra. Gúbio Reis</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Representante</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">gubio_reis0@example.com</th><td class="px-6 py-4">gubio.reis</td><td class="px-6 py-4">Acre</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/1230.jpg" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Melissa Saraiva Filho</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Atentende</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">melissa_saraiva@example.com</th><td class="px-6 py-4">melissa.saraiva70</td><td class="px-6 py-4">Sergipe</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/634.jpg" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Rafaela Barros</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Assistente</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">rafaela_barros44@example.net</th><td class="px-6 py-4">rafaela_barros12</td><td class="px-6 py-4">Rondônia</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://avatars.githubusercontent.com/u/79010193" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Júlio Xavier</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Produtor</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">julio.xavier@example.org</th><td class="px-6 py-4">julio.xavier8</td><td class="px-6 py-4">Amapá</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://avatars.githubusercontent.com/u/17326553" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Lorraine Melo Filho</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Associado</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">lorraine.melo@example.com</th><td class="px-6 py-4">lorraine.melo25</td><td class="px-6 py-4">Goiás</td></tr><tr class="bg-white border-b dark:bg-gray-800 dark:border-gray-700 hover:bg-gray-50 dark:hover:bg-gray-600"><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white"><img src="https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/1072.jpg" class="w-32 rounded-full"></th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Sirineu Moreira</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">Estrategista</th><th scope="row" class="px-6 py-4 font-medium text-gray-900 whitespace-nowrap dark:text-white">sirineu.moreira@example.org</th><td class="px-6 py-4">sirineu.moreira90</td><td class="px-6 py-4">Distrito Federal</td></tr>
</tbody>
"""
linhas = dados.find_elements(By.CSS_SELECTOR, 'tbody tr')
linhas
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5090d866c4b6cb2f89cf28e04e5e1526", element="f.22751EF508D4BC5157A743CF572D2313.d.7D2119D10D542729E59FCF6E22462972.e.15")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5090d866c4b6cb2f89cf28e04e5e1526", element="f.22751EF508D4BC5157A743CF572D2313.d.7D2119D10D542729E59FCF6E22462972.e.16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5090d866c4b6cb2f89cf28e04e5e1526", element="f.22751EF508D4BC5157A743CF572D2313.d.7D2119D10D542729E59FCF6E22462972.e.17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5090d866c4b6cb2f89cf28e04e5e1526", element="f.22751EF508D4BC5157A743CF572D2313.d.7D2119D10D542729E59FCF6E22462972.e.18")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5090d866c4b6cb2f89cf28e04e5e1526", element="f.22751EF508D4BC5157A743CF572D2313.d.7D2119D10D542729E59FCF6E22462972.e.19")>,
# ...

# %%
# cria classe com dataclass

@dataclass
class Usuario:
    avatar: str
    nome: str
    profissao: str
    email: str
    perfil: str
    estado: str

# %%
registros = []

for linha in linhas:  # tr = linha
    colunas = linha.get_property('children')  # th = coluna
    i = 0
    for coluna in colunas:
        print(str(i),'=', coluna.text, '|', end='')
        i+=1

    print('\n')

    usuario = Usuario(
        avatar=colunas[0].find_element(By.TAG_NAME, 'img').get_property('src'),
        nome=colunas[1].text,
        profissao=colunas[2].text,
        email=colunas[3].text,
        perfil=colunas[4].text,
        estado=colunas[5].text
    )
    registros.append(usuario)

for i, user in enumerate(registros, start=1):
    print(i, user.email)
# Out:
# 0 =  |1 = Elisa Melo |2 = Facilitador |3 = elisa_melo@example.net |4 = elisa.melo96 |5 = Pará |
#
# 0 =  |1 = Júlio César Santos |2 = Administrador |3 = juliocesar.santos85@example.net |4 = juliocesar.santos |5 = Paraíba |
#
# 0 =  |1 = Davi Lucca Barros |2 = Facilitador |3 = davilucca.barros89@example.net |4 = davilucca_barros |5 = Goiás |
#
# 0 =  |1 = Maria Macedo |2 = Designer |3 = maria.macedo74@example.net |4 = maria_macedo36 |5 = Tocantins |
#
# 0 =  |1 = Fábio Reis |2 = Supervisor |3 = fabio_reis@example.com |4 = fabio.reis46 |5 = Minas Gerais |
#
# 0 =  |1 = Rafael Silva |2 = Administrador |3 = rafael.silva@example.org |4 = rafael_silva |5 = Acre |
#
# 0 =  |1 = Lucas Franco Filho |2 = Técnico |3 = lucas_franco73@example.net |4 = lucas.franco |5 = Rio Grande do Sul |
#
# 0 =  |1 = Felícia Moraes |2 = Executivo |3 = felicia.moraes34@example.com |4 = felicia.moraes |5 = Amapá |
#
# ...

# %%
# selecionar botao proximo
# Praticar XPATH
"""
//*[@id="root"]/div/div[2]/main/div[2]/div/div[3]/button[2]
"""
proximo = chrome.find_element(By.XPATH, '//main//button[contains(text(), "Próxima")]')
proximo.click()  # Na ultima pagina dará erro

#voltar a primeira
anterior = chrome.find_element(By.XPATH, '//main//button[contains(text(), "Anterior")]')
anterior.click()  # Na ultima pagina dará erro

# %% [markdown]
# Refatorando

# %%
def raspar_dados_tabela():
    registros = []
    linhas = chrome.find_elements(By.CSS_SELECTOR, '#tabela-usuarios tbody tr')
    
    for linha in linhas:  # tr = linha
        colunas = linha.get_property('children')  # th = coluna
        
        usuario = Usuario(
            avatar=colunas[0].find_element(By.TAG_NAME, 'img').get_property('src'),
            nome=colunas[1].text,
            profissao=colunas[2].text,
            email=colunas[3].text,
            perfil=colunas[4].text,
            estado=colunas[5].text
        )
        registros.append(usuario)
    
    return registros

# %%
raspar_dados_tabela()
# Out:
# [Usuario(avatar='https://avatars.githubusercontent.com/u/90551384', nome='Elisa Melo', profissao='Facilitador', email='elisa_melo@example.net', perfil='elisa.melo96', estado='Pará'),
#  Usuario(avatar='https://avatars.githubusercontent.com/u/98392047', nome='Júlio César Santos', profissao='Administrador', email='juliocesar.santos85@example.net', perfil='juliocesar.santos', estado='Paraíba'),
#  Usuario(avatar='https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/521.jpg', nome='Davi Lucca Barros', profissao='Facilitador', email='davilucca.barros89@example.net', perfil='davilucca_barros', estado='Goiás'),
#  Usuario(avatar='https://cloudflare-ipfs.com/ipfs/Qmd3W5DuhgHirLHGVixi6V76LhCkZUz6pnFt5AJBiyvHye/avatar/127.jpg', nome='Maria Macedo', profissao='Designer', email='maria.macedo74@example.net', perfil='maria_macedo36', estado='Tocantins'),
# ...

# %%
lista_usuarios = []  # lista de usuarios do site
total_pagina = 0
# Raspagem da Paginacao até condição de saída.
while True:
    total_pagina +=1
    dados_pagina = raspar_dados_tabela()  # Raspa pagina atual
    lista_usuarios.extend(dados_pagina) # inclui lista da pagina na lista do site

    #Se não conseguir clicar em Próxima - Chegou na Ultima Pagina
    try:
        proximo = chrome.find_element(By.XPATH, '//main//button[contains(text(), "Próxima")]')
        proximo.click()  # Na ultima pagina dará erro
    except Exception as e:
        print('Não tem próxima')
        break  # Paralisa raspagem

print('Paginas=', total_pagina, ' Usuarios=', len(lista_usuarios))
# Out:
# Não tem próxima
# Paginas= 10  Usuarios= 100
