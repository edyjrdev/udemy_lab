# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.common import NoSuchElementException, TimeoutException
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

chrome = webdriver.Chrome()
# Pandas
import pandas as pd
# tratar HTML como arquivo para o Pandas
from io import StringIO

# %%
# Exemplo 01
# https://curso-web-scraping.pages.dev/#/exemplo/8
# server local
pagina = 'https://curso-web-scraping.pages.dev/#/exemplo/8'
chrome.get(pagina)
chrome.implicitly_wait(time_to_wait=10)  # aguardar 10 seg antes de levantar exceção

# %%
# String longa da url para conversão do StringIO - Evitar pandas procurar arquivo local

# ler tabela com pandas e lxml
# pd.read_html(io=) string io longa confunde pandas. StringIO garante url.
str_io = StringIO(chrome.page_source)
filtro = {'id':'tabela-usuarios'}

lista_tabelas = pd.read_html(io=str_io, attrs=filtro)  # busca elementos table na pagina e pega text da tabela
lista_tabelas[0]
# Out:
#    Avatar         Nome completo     Profissão  \
# 0     NaN           Rebeca Melo      Policial
# 1     NaN            Ígor Costa        Agente
# 2     NaN  Dr. Tertuliano Silva  Estrategista
# 3     NaN   Dra. Roberta Franco   Facilitador
# 4     NaN        Ofélia Martins     Executivo
# 5     NaN             Liz Costa        Agente
# 6     NaN  Maria Clara Oliveira     Arquiteto
# 7     NaN       Alessandra Reis   Facilitador
# 8     NaN         Talita Santos     Associado
# 9     NaN      Salvador Batista  Estrategista
#
#                               E-mail                 Perfil            Estado
# 0          rebeca_melo17@example.net            rebeca.melo  Distrito Federal
# 1           igor_costa82@example.org           igor_costa87       Mato Grosso
# 2     tertuliano_silva25@example.com       tertuliano.silva              Pará
# 3         roberta_franco@example.org       roberta.franco39       Mato Grosso
# ...
